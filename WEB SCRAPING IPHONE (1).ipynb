# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# ...

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/search?q=iphone+13&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=iphone+13%7CMobiles&requestId=262f923d-6e37-4e05-8dda-c81326668171&as-searchtext=iphione"

# %%
r=requests.get(url)

r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4a7b8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" 
# ...

# %%
soup = BeautifulSoup(r.content, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4a7b8.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
soup.title
# Out:
# <title>Iphone 13- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
soup.title.string
# Out:
# 'Iphone 13- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
soup.div
# Out:
# <div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="iphone 13"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g f
# ...

# %%
soup.a
# Out:
# <a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>

# %%
soup.find_all("a")
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Diphone%2B13%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Diphone%2B13%257CMobiles%26requestId%3D262f923d-6e37-4e05-8dda-c81326668171%26as-searchtext%3Diphione">Login</a>,
#  <a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
all_link=soup.find_all("a")
for r in all_link:
    print(r.get("href"))
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Diphone%2B13%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_7_sc_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Diphone%2B13%257CMobiles%26requestId%3D262f923d-6e37-4e05-8dda-c81326668171%26as-searchtext%3Diphione
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?exploreMode=true&preference=FLIPKART
# /mobiles-accessories/pr?sid=tyy&q=iphone+13&otracker=categorytree
# /mobiles/pr?sid=tyy,4io&q=iphone+13&otracker=categorytree
# /buying-guide/mobiles?sid=tyy,4io&otracker=bg_from_browse_lhs
# /
# /mobiles-accessories/pr?sid=tyy&marketplace=FLIPKART
# /mobiles/pr?sid=tyy,4io&marketplace=FLIPKART
# ...

# %%
model=soup.findAll('div',{'class':"_4rR01T"})

# %%
model
# Out:
# [<div class="_4rR01T">APPLE iPhone 13 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 ((PRODUCT)RED, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Green, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Pink, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Green, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Starlight, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Pink, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 ((PRODUCT)RED, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Blue, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Midnight, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Pink, 512 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 ((PRODUCT)RED, 512 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Green, 512 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Blue, 512 GB)</div>,
# ...

# %%
productname=[]
for i in model:
    p=i.text
    productname.append(p)
    
print(productname)
# Out:
# ['APPLE iPhone 13 (Starlight, 128 GB)', 'APPLE iPhone 13 (Blue, 128 GB)', 'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)', 'APPLE iPhone 13 (Green, 128 GB)', 'APPLE iPhone 13 (Pink, 128 GB)', 'APPLE iPhone 13 (Green, 256 GB)', 'APPLE iPhone 13 (Starlight, 256 GB)', 'APPLE iPhone 13 (Pink, 256 GB)', 'APPLE iPhone 13 ((PRODUCT)RED, 256 GB)', 'APPLE iPhone 13 (Blue, 256 GB)', 'APPLE iPhone 13 (Midnight, 256 GB)', 'APPLE iPhone 13 (Pink, 512 GB)', 'APPLE iPhone 13 ((PRODUCT)RED, 512 GB)', 'APPLE iPhone 13 (Green, 512 GB)', 'APPLE iPhone 13 (Blue, 512 GB)', 'APPLE iPhone 13 (Starlight, 512 GB)', 'APPLE iPhone 13 (Midnight, 512 GB)', 'APPLE iPhone 11 (White, 128 GB)', 'APPLE iPhone 11 (Black, 128 GB)', 'APPLE iPhone 11 (Green, 128 GB)', 'APPLE iPhone 11 (Purple, 128 GB)', 'APPLE iPhone 12 (Blue, 256 GB)', 'APPLE iPhone 11 (Green, 64 GB)', 'APPLE iPhone 11 (White, 64 GB)']

# %%
prices=soup.findAll('div',{'class':"_30jeq3 _1_WHN1"})

# %%
prices
# Out:
# [<div class="_30jeq3 _1_WHN1">₹65,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹65,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹65,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹65,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹65,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹75,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹95,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,999</div>,
# ...

# %%
r=soup.findAll('div',{'class':"_3LWZlK"})
rating=[]
for i in r:
    ra=i.text
    rating.append(ra)

print(rating)
# Out:
# ['4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '5', '3', '4.6', '5', '1', '4.6', '5', '3']

# %%
len(rating)
# Out:
# 33

# %%
len(prices)
# Out:
# 24

# %%
len(model)
# Out:
# 24

# %%
rating=rating[0:24]

# %%
rating
# Out:
# ['4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6']

# %%
len(rating)
# Out:
# 24

# %%
len(prices)
# Out:
# 24

# %%
len(productname)
# Out:
# 24

# %%
import pandas as pd
d={'productname':productname,'prices':prices,'rating':rating }
data=pd.DataFrame(d)
data
# Out:
#                                productname     prices rating
# 0      APPLE iPhone 13 (Starlight, 128 GB)  [₹65,999]    4.6
# 1           APPLE iPhone 13 (Blue, 128 GB)  [₹65,999]    4.6
# 2   APPLE iPhone 13 ((PRODUCT)RED, 128 GB)  [₹65,999]    4.6
# 3          APPLE iPhone 13 (Green, 128 GB)  [₹65,999]    4.6
# 4           APPLE iPhone 13 (Pink, 128 GB)  [₹65,999]    4.6
# 5          APPLE iPhone 13 (Green, 256 GB)  [₹75,999]    4.6
# 6      APPLE iPhone 13 (Starlight, 256 GB)  [₹75,999]    4.6
# 7           APPLE iPhone 13 (Pink, 256 GB)  [₹75,999]    4.6
# 8   APPLE iPhone 13 ((PRODUCT)RED, 256 GB)  [₹75,999]    4.6
# 9           APPLE iPhone 13 (Blue, 256 GB)  [₹75,999]    4.6
# 10      APPLE iPhone 13 (Midnight, 256 GB)  [₹75,999]    4.6
# 11          APPLE iPhone 13 (Pink, 512 GB)  [₹95,999]    4.6
# 12  APPLE iPhone 13 ((PRODUCT)RED, 512 GB)  [₹95,999]    4.6
# 13         APPLE iPhone 13 (Green, 512 GB)  [₹95,999]    4.6
# ...
